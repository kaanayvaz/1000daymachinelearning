# %%
import pandas as pd

data = pd.read_csv("/Users/omerkaanayvaz/Desktop/python_bu_sefer_bitti/1000daymachinelearning/DAY_4/dof-summary-of-neighborhood-sales-citywide-for-class-1-2-and-3-family-homes-2009-1.csv")

data.head()
# Out:
#   BOROUGH BUILDING CLASS CATEGORY   NUMBER OF SALES    MINIMUM SALE PRICE
# 0       1   01 ONE FAMILY HOMES                   55              408771.0  \
# 1       1   02 TWO FAMILY HOMES                   47              320000.0
# 2       1   03 THREE FAMILY HOMES                 33              449249.0
# 3       2   01 ONE FAMILY HOMES                  516              150000.0
# 4       2   02 TWO FAMILY HOMES                  771              150000.0
#
#     AVERAGE SALE PRICE    MEDIAN SALE PRICE    MAXIMUM SALE PRICE
# 0             6812888.0            5075000.0            25000000.0
# 1             3736718.0            3085000.0            15400000.0
# 2             2857128.0            1100000.0            19500000.0
# 3              405594.0             349995.0             5000000.0
# 4              421473.0             428786.0             1000000.0

# %%
data.isnull().sum()
# Out:
# BOROUGH                    1
# BUILDING CLASS CATEGORY    1
#  NUMBER OF SALES           0
#  MINIMUM SALE PRICE        1
#  AVERAGE SALE PRICE        1
#  MEDIAN SALE PRICE         1
#  MAXIMUM SALE PRICE        1
# dtype: int64

# %%
data.fillna(0)
# Out:
#      BOROUGH BUILDING CLASS CATEGORY   NUMBER OF SALES    MINIMUM SALE PRICE
# 0          1   01 ONE FAMILY HOMES                   55              408771.0  \
# 1          1   02 TWO FAMILY HOMES                   47              320000.0
# 2          1   03 THREE FAMILY HOMES                 33              449249.0
# 3          2   01 ONE FAMILY HOMES                  516              150000.0
# 4          2   02 TWO FAMILY HOMES                  771              150000.0
# 5          2   03 THREE FAMILY HOMES                276              150000.0
# 6          3   01 ONE FAMILY HOMES                 1394              150000.0
# 7          3   02 TWO FAMILY HOMES                 2375              150000.0
# 8          3   03 THREE FAMILY HOMES                841              150000.0
# 9          4   01 ONE FAMILY HOMES                 4714              150000.0
# 10         4   02 TWO FAMILY HOMES                 3402              150000.0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dropna()
# Out:
#      BOROUGH BUILDING CLASS CATEGORY   NUMBER OF SALES    MINIMUM SALE PRICE
# 0          1   01 ONE FAMILY HOMES                   55              408771.0  \
# 1          1   02 TWO FAMILY HOMES                   47              320000.0
# 2          1   03 THREE FAMILY HOMES                 33              449249.0
# 3          2   01 ONE FAMILY HOMES                  516              150000.0
# 4          2   02 TWO FAMILY HOMES                  771              150000.0
# 5          2   03 THREE FAMILY HOMES                276              150000.0
# 6          3   01 ONE FAMILY HOMES                 1394              150000.0
# 7          3   02 TWO FAMILY HOMES                 2375              150000.0
# 8          3   03 THREE FAMILY HOMES                841              150000.0
# 9          4   01 ONE FAMILY HOMES                 4714              150000.0
# 10         4   02 TWO FAMILY HOMES                 3402              150000.0
# ...

# %%
data = data[data[" NUMBER OF SALES "] > 1000]

# %%
sale_price = data[" AVERAGE SALE PRICE "].sum() / data[" NUMBER OF SALES "].sum()

print(f"Avarage sale price is: {sale_price}")
# Out:
# Avarage sale price is: 83.47103274559194

# %%
data.head()
# Out:
#    BOROUGH BUILDING CLASS CATEGORY   NUMBER OF SALES    MINIMUM SALE PRICE
# 6        3   01 ONE FAMILY HOMES                 1394              150000.0  \
# 7        3   02 TWO FAMILY HOMES                 2375              150000.0
# 9        4   01 ONE FAMILY HOMES                 4714              150000.0
# 10       4   02 TWO FAMILY HOMES                 3402              150000.0
# 12       5   01 ONE FAMILY HOMES                 2214              150000.0
#
#      AVERAGE SALE PRICE    MEDIAN SALE PRICE    MAXIMUM SALE PRICE
# 6               580687.0             475000.0            10260000.0
# 7               591108.0             538888.0            10979100.0
# 9               461437.0             425000.0             3775000.0
# 10              496094.0             480000.0             3500000.0
# 12              401442.0             375000.0             4000000.0
